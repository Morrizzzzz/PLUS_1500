# %%
for i in range(4, 38):  # to generate claim_4 and claim_5
    print(f"""attribute<costdist> claim_{i} (rdc_100lu)
\t\t: = 1 [float32] * (start_situation/Thematic_maps/claim_regions/claim_regions) [float32]
\t\t* iif(start_situation/Thematic_maps/claim_regions/claim_regions == value({i}, float32), value(1, float32), value(0, float32)) [float32]\t\t
\t\t;""")
# Out:
# attribute<costdist> claim_4 (rdc_100lu)
# 		: = 1 [float32] * (start_situation/Thematic_maps/claim_regions/claim_regions) [float32]
# 		* iif(start_situation/Thematic_maps/claim_regions/claim_regions == value(4, float32), value(1, float32), value(0, float32)) [float32]
# 		;
# attribute<costdist> claim_5 (rdc_100lu)
# 		: = 1 [float32] * (start_situation/Thematic_maps/claim_regions/claim_regions) [float32]
# 		* iif(start_situation/Thematic_maps/claim_regions/claim_regions == value(5, float32), value(1, float32), value(0, float32)) [float32]
# 		;
# attribute<costdist> claim_6 (rdc_100lu)
# 		: = 1 [float32] * (start_situation/Thematic_maps/claim_regions/claim_regions) [float32]
# 		* iif(start_situation/Thematic_maps/claim_regions/claim_regions == value(6, float32), value(1, float32), value(0, float32)) [float32]
# 		;
# attribute<costdist> claim_7 (rdc_100lu)
# 		: = 1 [float32] * (start_situation/Thematic_maps/claim_regions/claim_regions) [float32]
# ...

# %%
for i in range(4, 38):  # to generate claim_4 and claim_5
    print(f"""attribute<ggHa> removed_wood_claim{i} (rdc_100lu)
\t\t: = (removed_wood*claim_{i}) / {i} [float32]""")
# Out:
# attribute<ggHa> removed_wood_claim4 (rdc_100lu)
# 		: = (removed_wood*claim_4) / 4 [float32]
# attribute<ggHa> removed_wood_claim5 (rdc_100lu)
# 		: = (removed_wood*claim_5) / 5 [float32]
# attribute<ggHa> removed_wood_claim6 (rdc_100lu)
# 		: = (removed_wood*claim_6) / 6 [float32]
# attribute<ggHa> removed_wood_claim7 (rdc_100lu)
# 		: = (removed_wood*claim_7) / 7 [float32]
# attribute<ggHa> removed_wood_claim8 (rdc_100lu)
# 		: = (removed_wood*claim_8) / 8 [float32]
# attribute<ggHa> removed_wood_claim9 (rdc_100lu)
# 		: = (removed_wood*claim_9) / 9 [float32]
# attribute<ggHa> removed_wood_claim10 (rdc_100lu)
# 		: = (removed_wood*claim_10) / 10 [float32]
# attribute<ggHa> removed_wood_claim11 (rdc_100lu)
# 		: = (removed_wood*claim_11) / 11 [float32]
# attribute<ggHa> removed_wood_claim12 (rdc_100lu)
# 		: = (removed_wood*claim_12) / 12 [float32]
# attribute<ggHa> removed_wood_claim13 (rdc_100lu)
# 		: = (removed_wood*claim_13) / 13 [float32]
# ...

# %%
		attribute<ggHa> agriculture_claim1 (rdc_100lu)
		: = (results/continuous/landuse/Endogenous/agriculture*claim_1) / 1 [float32]
		;

# %%
for i in range(4, 38):  # to generate claim_4 and claim_5
    print(f"""\t\tattribute<ggHa> agriculture_claim{i} (rdc_100lu)
\t\t: = (results/continuous/landuse/Endogenous/agriculture*claim_{i}) / {i} [float32]
\t\t;""")
# Out:
# 		attribute<ggHa> agriculture_claim4 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/agriculture*claim_4) / 4 [float32]
# 		;
# 		attribute<ggHa> agriculture_claim5 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/agriculture*claim_5) / 5 [float32]
# 		;
# 		attribute<ggHa> agriculture_claim6 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/agriculture*claim_6) / 6 [float32]
# 		;
# 		attribute<ggHa> agriculture_claim7 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/agriculture*claim_7) / 7 [float32]
# 		;
# 		attribute<ggHa> agriculture_claim8 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/agriculture*claim_8) / 8 [float32]
# 		;
# 		attribute<ggHa> agriculture_claim9 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/agriculture*claim_9) / 9 [float32]
# 		;
# 		attribute<ggHa> agriculture_claim10 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/agriculture*claim_10) / 10 [float32]
# 		;
# ...

# %%
for i in range(4, 38):  # to generate claim_4 and claim_5
    print(f"""\t\tattribute<ggHa> grassland_claim{i} (rdc_100lu)
\t\t: = (results/continuous/landuse/Endogenous/grassland*claim_{i}) / {i} [float32]
\t\t;
""")
# Out:
# 		attribute<ggHa> grassland_claim4 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/grassland*claim_4) / 4 [float32]
# 		;
#
# 		attribute<ggHa> grassland_claim5 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/grassland*claim_5) / 5 [float32]
# 		;
#
# 		attribute<ggHa> grassland_claim6 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/grassland*claim_6) / 6 [float32]
# 		;
#
# 		attribute<ggHa> grassland_claim7 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/grassland*claim_7) / 7 [float32]
# 		;
#
# 		attribute<ggHa> grassland_claim8 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/grassland*claim_8) / 8 [float32]
# 		;
#
# 		attribute<ggHa> grassland_claim9 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/grassland*claim_9) / 9 [float32]
# 		;
#
# 		attribute<ggHa> grassland_claim10 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/grassland*claim_10) / 10 [float32]
# 		;
#
# ...

# %%
for i in range(4, 38):  # to generate claim_4 and claim_5
    print(f"""\t\tattribute<ggHa> hay_land_claim{i} (rdc_100lu)
\t\t: = (results/continuous/landuse/Endogenous/hay_land*claim_{i}) / {i} [float32]
\t\t;
""")
# Out:
# 		attribute<ggHa> hay_land_claim4 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/hay_land*claim_4) / 4 [float32]
# 		;
#
# 		attribute<ggHa> hay_land_claim5 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/hay_land*claim_5) / 5 [float32]
# 		;
#
# 		attribute<ggHa> hay_land_claim6 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/hay_land*claim_6) / 6 [float32]
# 		;
#
# 		attribute<ggHa> hay_land_claim7 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/hay_land*claim_7) / 7 [float32]
# 		;
#
# 		attribute<ggHa> hay_land_claim8 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/hay_land*claim_8) / 8 [float32]
# 		;
#
# 		attribute<ggHa> hay_land_claim9 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/hay_land*claim_9) / 9 [float32]
# 		;
#
# 		attribute<ggHa> hay_land_claim10 (rdc_100lu)
# 		: = (results/continuous/landuse/Endogenous/hay_land*claim_10) / 10 [float32]
# 		;
#
# 		attribute<ggHa> hay_land_claim11 (rdc_100lu)
# ...

# %%
for i in range(4, 38):  # to generate claim_4 and claim_5
    print(f"""\t\t\tauattribute<claimHa> 		claim{i}			(RegioUnit):								= sum(claim_regions/removed_wood_claim{i}, RegioGrids/paleo),
          \tStorageName     	= "%projDir%/data/export/evaluation/wood_palaeo_claim_{i}.dbf";""")
# Out:
# 		attribute<claimHa> 		claim4			(RegioUnit):								= sum(claim_regions/removed_wood_claim4, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/wood_palaeo_claim_4.dbf";
# 		attribute<claimHa> 		claim5			(RegioUnit):								= sum(claim_regions/removed_wood_claim5, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/wood_palaeo_claim_5.dbf";
# 		attribute<claimHa> 		claim6			(RegioUnit):								= sum(claim_regions/removed_wood_claim6, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/wood_palaeo_claim_6.dbf";
# 		attribute<claimHa> 		claim7			(RegioUnit):								= sum(claim_regions/removed_wood_claim7, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/wood_palaeo_claim_7.dbf";
# 		attribute<claimHa> 		claim8			(RegioUnit):								= sum(claim_regions/removed_wood_claim8, RegioGrids/paleo),
# ...

# %%
for i in range(4, 38):  # to generate claim_4 and claim_5
    print(f"""\t\t\tattribute<claimHa> 		claim{i}			(RegioUnit):								= sum(claim_regions/agriculture_claim{i}, RegioGrids/paleo),
          \tStorageName     	= "%projDir%/data/export/evaluation/agriculture_claim_{i}.dbf";""")
# Out:
# 			attribute<claimHa> 		claim4			(RegioUnit):								= sum(claim_regions/agriculture_claim4, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/agriculture_claim_4.dbf";
# 			attribute<claimHa> 		claim5			(RegioUnit):								= sum(claim_regions/agriculture_claim5, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/agriculture_claim_5.dbf";
# 			attribute<claimHa> 		claim6			(RegioUnit):								= sum(claim_regions/agriculture_claim6, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/agriculture_claim_6.dbf";
# 			attribute<claimHa> 		claim7			(RegioUnit):								= sum(claim_regions/agriculture_claim7, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/agriculture_claim_7.dbf";
# 			attribute<claimHa> 		claim8			(RegioUnit):								= sum(claim_regions/agriculture_claim8, RegioGrids/paleo),
# ...

# %%
for i in range(4, 38):  # to generate claim_4 and claim_5
    print(f"""\t\t\tattribute<claimHa> 		claim{i}			(RegioUnit):								= sum(claim_regions/grassland_claim{i}, RegioGrids/paleo),
          \tStorageName     	= "%projDir%/data/export/evaluation/grassland_claim_{i}.dbf";""")
# Out:
# 			attribute<claimHa> 		claim4			(RegioUnit):								= sum(claim_regions/grassland_claim4, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/grassland_claim_4.dbf";
# 			attribute<claimHa> 		claim5			(RegioUnit):								= sum(claim_regions/grassland_claim5, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/grassland_claim_5.dbf";
# 			attribute<claimHa> 		claim6			(RegioUnit):								= sum(claim_regions/grassland_claim6, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/grassland_claim_6.dbf";
# 			attribute<claimHa> 		claim7			(RegioUnit):								= sum(claim_regions/grassland_claim7, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/grassland_claim_7.dbf";
# 			attribute<claimHa> 		claim8			(RegioUnit):								= sum(claim_regions/grassland_claim8, RegioGrids/paleo),
# ...

# %%
for i in range(4, 38):  # to generate claim_4 and claim_5
    print(f"""\t\t\tattribute<claimHa> 		claim{i}			(RegioUnit):								= sum(claim_regions/hay_land_claim{i}, RegioGrids/paleo),
          \tStorageName     	= "%projDir%/data/export/evaluation/hay_land_claim_{i}.dbf";""")
# Out:
# 			attribute<claimHa> 		claim4			(RegioUnit):								= sum(claim_regions/hay_land_claim4, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/hay_land_claim_4.dbf";
# 			attribute<claimHa> 		claim5			(RegioUnit):								= sum(claim_regions/hay_land_claim5, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/hay_land_claim_5.dbf";
# 			attribute<claimHa> 		claim6			(RegioUnit):								= sum(claim_regions/hay_land_claim6, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/hay_land_claim_6.dbf";
# 			attribute<claimHa> 		claim7			(RegioUnit):								= sum(claim_regions/hay_land_claim7, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/hay_land_claim_7.dbf";
# 			attribute<claimHa> 		claim8			(RegioUnit):								= sum(claim_regions/hay_land_claim8, RegioGrids/paleo),
#           	StorageName     	= "%projDir%/data/export/evaluation/hay_land_claim_8.dbf";
# ...
